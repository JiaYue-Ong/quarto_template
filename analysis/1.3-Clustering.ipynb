# %% [markdown]
# ---
# title: "3. Clustering"
# format:
#   html:
#     toc: false
#     page-layout: full
#     code-fold: true
# execute:
#     echo: false
#     warning: false
# ---

# %%
#| echo: false
#| code-fold: true
#| include: false

# !pip install cenpy
import cenpy
import numpy as np
np.random.seed(42)
# Out:
# Requirement already satisfied: cenpy in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (1.0.1)
# Requirement already satisfied: pandas in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from cenpy) (1.5.3)
# Requirement already satisfied: geopandas in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from cenpy) (0.13.2)
# Requirement already satisfied: requests in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from cenpy) (2.31.0)
# Requirement already satisfied: rtree in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from cenpy) (1.3.0)
# Requirement already satisfied: numpy in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from cenpy) (1.24.4)
# Requirement already satisfied: six in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from cenpy) (1.16.0)
# Requirement already satisfied: fuzzywuzzy in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from cenpy) (0.18.0)
# Requirement already satisfied: libpysal in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from cenpy) (4.12.1)
# Requirement already satisfied: fiona>=1.8.19 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from geopandas->cenpy) (1.9.4)
# Requirement already satisfied: packaging in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from geopandas->cenpy) (24.1)
# Requirement already satisfied: pyproj>=3.0.1 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from geopandas->cenpy) (3.6.1)
# Requirement already satisfied: shapely>=1.7.1 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from geopandas->cenpy) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from pandas->cenpy) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from pandas->cenpy) (2024.1)
# Requirement already satisfied: beautifulsoup4>=4.10 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from libpysal->cenpy) (4.12.2)
# Requirement already satisfied: platformdirs>=2.0.2 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from libpysal->cenpy) (4.2.2)
# Requirement already satisfied: scipy>=1.8 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from libpysal->cenpy) (1.14.1)
# Requirement already satisfied: scikit-learn>=1.1 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from libpysal->cenpy) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from requests->cenpy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from requests->cenpy) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from requests->cenpy) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from requests->cenpy) (2024.7.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from beautifulsoup4>=4.10->libpysal->cenpy) (2.5)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from fiona>=1.8.19->geopandas->cenpy) (24.2.0)
# Requirement already satisfied: click~=8.0 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from fiona>=1.8.19->geopandas->cenpy) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from fiona>=1.8.19->geopandas->cenpy) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from fiona>=1.8.19->geopandas->cenpy) (0.7.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from scikit-learn>=1.1->libpysal->cenpy) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from scikit-learn>=1.1->libpysal->cenpy) (3.5.0)
# Requirement already satisfied: colorama in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from click~=8.0->fiona>=1.8.19->geopandas->cenpy) (0.4.6)

# %%
#| echo: false
#| code-fold: true
#| include: false

# Finding data set
available = cenpy.explorer.available()
available

# We use data from ACS 5 Year, Monthly Export and Import
# Out:
#                 c_isTimeseries   temporal        spatial c_isAggregate  \
# ABSCB2017                  NaN  2017/2017  United States          True
# ABSCB2018                  NaN  2018/2018  United States          True
# ABSCB2019                  NaN  2019/2019             US          True
# ABSCB2020                  NaN  2020/2020             US          True
# ABSCB2021                  NaN  2021/2021  United States          True
# ...                        ...        ...            ...           ...
# ftd16ImpExpHist            NaN  2016/2016  United States          True
# ftd17ImpExpHist            NaN  2017/2017  United States          True
# ftd18ImpExpHist            NaN  2018/2018  United States          True
# ftdImpExpHist              NaN  2014/2014  United States          True
# pubschlfin2012             NaN  2012/2012  United States          True
#
#                           publisher                          references  \
# ABSCB2017        U.S. Census Bureau  https://www.census.gov/developers/
# ABSCB2018        U.S. Census Bureau  https://www.census.gov/developers/
# ABSCB2019        U.S. Census Bureau  https://www.census.gov/developers/
# ABSCB2020        U.S. Census Bureau  https://www.census.gov/developers/
# ABSCB2021        U.S. Census Bureau  https://www.census.gov/developers/
# ...                             ...                                 ...
# ftd16ImpExpHist  U.S. Census Bureau   http://www.census.gov/developers/
# ftd17ImpExpHist  U.S. Census Bureau   http://www.census.gov/developers/
# ftd18ImpExpHist  U.S. Census Bureau   http://www.census.gov/developers/
# ftdImpExpHist    U.S. Census Bureau   http://www.census.gov/developers/
# pubschlfin2012   U.S. Census Bureau   http://www.census.gov/developers/
#
#                 programCode               modified  \
# ABSCB2017           006:007  2020-04-30 00:00:00.0
# ABSCB2018           006:007  2020-10-26 00:00:00.0
# ABSCB2019           006:007  2021-08-17 00:00:00.0
# ABSCB2020           006:007  2022-08-03 00:00:00.0
# ABSCB2021           006:007  2023-07-24 10:30:52.0
# ...                     ...                    ...
# ftd16ImpExpHist     000:000             2017-07-13
# ftd17ImpExpHist     000:000             2018-03-13
# ftd18ImpExpHist     000:000             2019-03-13
# ftdImpExpHist       000:000             2015-07-20
# pubschlfin2012      006:000             2014-09-30
#
#                                                            license    keyword  \
# ABSCB2017        https://creativecommons.org/publicdomain/zero/...  (census,)
# ABSCB2018        https://creativecommons.org/publicdomain/zero/...  (census,)
# ABSCB2019        https://creativecommons.org/publicdomain/zero/...  (census,)
# ABSCB2020        https://creativecommons.org/publicdomain/zero/...  (census,)
# ABSCB2021        https://creativecommons.org/publicdomain/zero/...  (census,)
# ...                                                            ...        ...
# ftd16ImpExpHist  http://creativecommons.org/publicdomain/zero/1.0/  (census,)
# ftd17ImpExpHist  http://creativecommons.org/publicdomain/zero/1.0/  (census,)
# ftd18ImpExpHist  http://creativecommons.org/publicdomain/zero/1.0/  (census,)
# ftdImpExpHist    http://creativecommons.org/publicdomain/zero/1.0/  (census,)
# pubschlfin2012   http://creativecommons.org/publicdomain/zero/1.0/  (census,)
#
#                  ...                                        description  \
# ABSCB2017        ...  The Annual Business Survey (ABS) provides info...
# ABSCB2018        ...  The Annual Business Survey (ABS) provides info...
# ABSCB2019        ...  The Annual Business Survey (ABS) provides info...
# ABSCB2020        ...  The Annual Business Survey (ABS) provides info...
# ABSCB2021        ...  The Annual Business Survey (ABS) provides info...
# ...              ...                                                ...
# ftd16ImpExpHist  ...  This international trade file provides the ann...
# ftd17ImpExpHist  ...  This international trade file provides the ann...
# ftd18ImpExpHist  ...  This international trade file provides the ann...
# ftdImpExpHist    ...  This international trade file provides the ann...
# pubschlfin2012   ...  The survey covers all public school systems th...
#
#                 bureauCode accessLevel  \
# ABSCB2017           006:07      public
# ABSCB2018           006:07      public
# ABSCB2019           006:07      public
# ABSCB2020           006:07      public
# ABSCB2021           006:07      public
# ...                    ...         ...
# ftd16ImpExpHist     006:07      public
# ftd17ImpExpHist     006:07      public
# ftd18ImpExpHist     006:07      public
# ftdImpExpHist       006:07      public
# pubschlfin2012      006:07      public
#
#                                                              title  \
# ABSCB2017        Annual Business Survey: Characteristics of Bus...
# ABSCB2018        Annual Business Survey: Characteristics of Bus...
# ABSCB2019        2019 Annual Business Survey: Characteristics o...
# ABSCB2020        2020 Annual Business Survey: Characteristics o...
# ABSCB2021        2021 Annual Business Survey: Characteristics o...
# ...                                                            ...
# ftd16ImpExpHist  2016 International Trade: Historical Imports a...
# ftd17ImpExpHist  2017 International Trade: Historical Imports a...
# ftd18ImpExpHist  2018 International Trade: Historical Imports a...
# ftdImpExpHist    2014 International Trade: Historical Imports a...
# pubschlfin2012   2012 Public Elementary-Secondary Education Fin...
#
#                 c_isAvailable c_isCube c_isMicrodata  \
# ABSCB2017                True      NaN           NaN
# ABSCB2018                True      NaN           NaN
# ABSCB2019                True      NaN           NaN
# ABSCB2020                True      NaN           NaN
# ABSCB2021                True      NaN           NaN
# ...                       ...      ...           ...
# ftd16ImpExpHist          True     True           NaN
# ftd17ImpExpHist          True     True           NaN
# ftd18ImpExpHist          True     True           NaN
# ftdImpExpHist            True     True           NaN
# pubschlfin2012           True      NaN           NaN
#
#                                c_documentationLink             c_dataset  \
# ABSCB2017        https://www.census.gov/developer/              (abscb,)
# ABSCB2018        https://www.census.gov/developer/              (abscb,)
# ABSCB2019        https://www.census.gov/developer/              (abscb,)
# ABSCB2020        https://www.census.gov/developer/              (abscb,)
# ABSCB2021        https://www.census.gov/developer/              (abscb,)
# ...                                            ...                   ...
# ftd16ImpExpHist   http://www.census.gov/developer/  (intltrade, imp_exp)
# ftd17ImpExpHist   http://www.census.gov/developer/  (intltrade, imp_exp)
# ftd18ImpExpHist   http://www.census.gov/developer/  (intltrade, imp_exp)
# ftdImpExpHist     http://www.census.gov/developer/  (intltrade, imp_exp)
# pubschlfin2012    http://www.census.gov/developer/         (pubschlfin,)
#
#                 vintage
# ABSCB2017        2017.0
# ABSCB2018        2018.0
# ABSCB2019        2019.0
# ABSCB2020        2020.0
# ABSCB2021        2021.0
# ...                 ...
# ftd16ImpExpHist  2016.0
# ftd17ImpExpHist  2017.0
# ftd18ImpExpHist  2018.0
# ftdImpExpHist    2014.0
# pubschlfin2012   2012.0
#
# [1665 rows x 23 columns]

# %%
#| echo: false
#| code-fold: true
#| include: false

acs = available.filter(regex="^ACS", axis=0)
available.filter(regex="^ACSDT5Y", axis=0)
# Out:
#                 c_isTimeseries   temporal        spatial c_isAggregate  \
# ACSDT5Y2009                NaN        NaN            NaN          True
# ACSDT5Y2010                NaN        NaN  United States          True
# ACSDT5Y2011                NaN        NaN            NaN          True
# ACSDT5Y2012                NaN        NaN            NaN          True
# ACSDT5Y2013                NaN        NaN            NaN          True
# ACSDT5Y2014                NaN        NaN            NaN          True
# ACSDT5Y2015                NaN        NaN            NaN          True
# ACSDT5Y2016                NaN        NaN            NaN          True
# ACSDT5Y2017                NaN        NaN            NaN          True
# ACSDT5Y2018                NaN        NaN            NaN          True
# ACSDT5Y2019                NaN        NaN            NaN          True
# ACSDT5Y2020                NaN  2020/2020             US          True
# ACSDT5Y2021                NaN  2021/2021             US          True
# ACSDT5Y2022                NaN  2022/2022             US          True
# ACSDT5Y2023                NaN  2023/2023             US          True
# ACSDT5YAIAN2010            NaN        NaN            NaN          True
# ACSDT5YAIAN2015            NaN        NaN            NaN          True
# ACSDT5YAIAN2021            NaN  2021/2021             US          True
# ACSDT5YSPT2010             NaN        NaN            NaN          True
# ACSDT5YSPT2015             NaN        NaN            NaN          True
# ACSDT5YSPT2021             NaN  2021/2021             US          True
#
#                           publisher                          references  \
# ACSDT5Y2009      U.S. Census Bureau  https://www.census.gov/developers/
# ACSDT5Y2010      U.S. Census Bureau  https://www.census.gov/developers/
# ACSDT5Y2011      U.S. Census Bureau  https://www.census.gov/developers/
# ACSDT5Y2012      U.S. Census Bureau  https://www.census.gov/developers/
# ACSDT5Y2013      U.S. Census Bureau  https://www.census.gov/developers/
# ACSDT5Y2014      U.S. Census Bureau  https://www.census.gov/developers/
# ACSDT5Y2015      U.S. Census Bureau  https://www.census.gov/developers/
# ACSDT5Y2016      U.S. Census Bureau  https://www.census.gov/developers/
# ACSDT5Y2017      U.S. Census Bureau  https://www.census.gov/developers/
# ACSDT5Y2018      U.S. Census Bureau  https://www.census.gov/developers/
# ACSDT5Y2019      U.S. Census Bureau  https://www.census.gov/developers/
# ACSDT5Y2020      U.S. Census Bureau  https://www.census.gov/developers/
# ACSDT5Y2021      U.S. Census Bureau  https://www.census.gov/developers/
# ACSDT5Y2022      U.S. Census Bureau  https://www.census.gov/developers/
# ACSDT5Y2023      U.S. Census Bureau  https://www.census.gov/developers/
# ACSDT5YAIAN2010  U.S. Census Bureau  https://www.census.gov/developers/
# ACSDT5YAIAN2015  U.S. Census Bureau  https://www.census.gov/developers/
# ACSDT5YAIAN2021  U.S. Census Bureau  https://www.census.gov/developers/
# ACSDT5YSPT2010   U.S. Census Bureau  https://www.census.gov/developers/
# ACSDT5YSPT2015   U.S. Census Bureau  https://www.census.gov/developers/
# ACSDT5YSPT2021   U.S. Census Bureau  https://www.census.gov/developers/
#
#                 programCode               modified  \
# ACSDT5Y2009         006:004  2019-08-27 13:11:18.0
# ACSDT5Y2010         006:004  2018-07-04 00:00:00.0
# ACSDT5Y2011         006:004  2018-07-04 00:00:00.0
# ACSDT5Y2012         006:004  2018-07-04 00:00:00.0
# ACSDT5Y2013         006:004  2018-07-04 00:00:00.0
# ACSDT5Y2014         006:004  2018-07-04 00:00:00.0
# ACSDT5Y2015         006:004  2018-07-05 00:00:00.0
# ACSDT5Y2016         006:004  2018-07-05 00:00:00.0
# ACSDT5Y2017         006:004  2018-08-21 07:11:43.0
# ACSDT5Y2018         006:004  2019-10-22 16:28:02.0
# ACSDT5Y2019         006:004  2020-04-03 00:00:00.0
# ACSDT5Y2020         006:004  2021-07-13 00:00:00.0
# ACSDT5Y2021         006:004  2022-08-08 00:00:00.0
# ACSDT5Y2022         006:004  2023-09-05 12:01:39.0
# ACSDT5Y2023         006:004  2024-09-06 17:27:47.0
# ACSDT5YAIAN2010     006:004  2019-10-24 07:18:57.0
# ACSDT5YAIAN2015     006:004  2020-02-13 00:00:00.0
# ACSDT5YAIAN2021     006:004  2022-11-29 00:00:00.0
# ACSDT5YSPT2010      006:004  2019-10-11 14:16:00.0
# ACSDT5YSPT2015      006:004  2020-02-18 00:00:00.0
# ACSDT5YSPT2021      006:004  2022-11-29 00:00:00.0
#
#                                                            license    keyword  \
# ACSDT5Y2009      https://creativecommons.org/publicdomain/zero/...  (census,)
# ACSDT5Y2010      https://creativecommons.org/publicdomain/zero/...  (census,)
# ACSDT5Y2011      https://creativecommons.org/publicdomain/zero/...  (census,)
# ACSDT5Y2012      https://creativecommons.org/publicdomain/zero/...  (census,)
# ACSDT5Y2013      https://creativecommons.org/publicdomain/zero/...  (census,)
# ACSDT5Y2014      https://creativecommons.org/publicdomain/zero/...  (census,)
# ACSDT5Y2015      https://creativecommons.org/publicdomain/zero/...  (census,)
# ACSDT5Y2016      https://creativecommons.org/publicdomain/zero/...  (census,)
# ACSDT5Y2017      https://creativecommons.org/publicdomain/zero/...  (census,)
# ACSDT5Y2018      https://creativecommons.org/publicdomain/zero/...  (census,)
# ACSDT5Y2019      https://creativecommons.org/publicdomain/zero/...  (census,)
# ACSDT5Y2020      https://creativecommons.org/publicdomain/zero/...  (census,)
# ACSDT5Y2021      https://creativecommons.org/publicdomain/zero/...  (census,)
# ACSDT5Y2022      https://creativecommons.org/publicdomain/zero/...  (census,)
# ACSDT5Y2023      https://creativecommons.org/publicdomain/zero/...  (census,)
# ACSDT5YAIAN2010  https://creativecommons.org/publicdomain/zero/...  (census,)
# ACSDT5YAIAN2015  https://creativecommons.org/publicdomain/zero/...  (census,)
# ACSDT5YAIAN2021  https://creativecommons.org/publicdomain/zero/...  (census,)
# ACSDT5YSPT2010   https://creativecommons.org/publicdomain/zero/...  (census,)
# ACSDT5YSPT2015   https://creativecommons.org/publicdomain/zero/...  (census,)
# ACSDT5YSPT2021   https://creativecommons.org/publicdomain/zero/...  (census,)
#
#                  ...                                        description  \
# ACSDT5Y2009      ...  The American Community Survey (ACS) is an ongo...
# ACSDT5Y2010      ...  The American Community Survey (ACS) is an ongo...
# ACSDT5Y2011      ...  The American Community Survey (ACS) is an ongo...
# ACSDT5Y2012      ...  The American Community Survey (ACS) is an ongo...
# ACSDT5Y2013      ...  The American Community Survey (ACS) is an ongo...
# ACSDT5Y2014      ...  The American Community Survey (ACS) is an ongo...
# ACSDT5Y2015      ...  The American Community Survey (ACS) is an ongo...
# ACSDT5Y2016      ...  The American Community Survey (ACS) is an ongo...
# ACSDT5Y2017      ...  The American Community Survey (ACS) is an ongo...
# ACSDT5Y2018      ...  The American Community Survey (ACS) is an ongo...
# ACSDT5Y2019      ...  The American Community Survey (ACS) is an ongo...
# ACSDT5Y2020      ...  The American Community Survey (ACS) is an ongo...
# ACSDT5Y2021      ...  The American Community Survey (ACS) is an ongo...
# ACSDT5Y2022      ...  The American Community Survey (ACS) is an ongo...
# ACSDT5Y2023      ...  The American Community Survey (ACS) is an ongo...
# ACSDT5YAIAN2010  ...  The American Indian and Alaska Native (AIAN) t...
# ACSDT5YAIAN2015  ...  The American Indian and Alaska Native (AIAN) t...
# ACSDT5YAIAN2021  ...  The American Indian and Alaska Native (AIAN) t...
# ACSDT5YSPT2010   ...  The Selected Population  Tables (SPT) are rele...
# ACSDT5YSPT2015   ...  The Selected Population  Tables (SPT) are rele...
# ACSDT5YSPT2021   ...  The Selected Population Tables (SPT) are relea...
#
#                 bureauCode accessLevel  \
# ACSDT5Y2009         006:07      public
# ACSDT5Y2010         006:07      public
# ACSDT5Y2011         006:07      public
# ACSDT5Y2012         006:07      public
# ACSDT5Y2013         006:07      public
# ACSDT5Y2014         006:07      public
# ACSDT5Y2015         006:07      public
# ACSDT5Y2016         006:07      public
# ACSDT5Y2017         006:07      public
# ACSDT5Y2018         006:07      public
# ACSDT5Y2019         006:07      public
# ACSDT5Y2020         006:07      public
# ACSDT5Y2021         006:07      public
# ACSDT5Y2022         006:07      public
# ACSDT5Y2023         006:07      public
# ACSDT5YAIAN2010     006:07      public
# ACSDT5YAIAN2015     006:07      public
# ACSDT5YAIAN2021     006:07      public
# ACSDT5YSPT2010      006:07      public
# ACSDT5YSPT2015      006:07      public
# ACSDT5YSPT2021      006:07      public
#
#                                                              title  \
# ACSDT5Y2009      American Community Survey: 5-Year Estimates: D...
# ACSDT5Y2010                             ACS 5-Year Detailed Tables
# ACSDT5Y2011                             ACS 5-Year Detailed Tables
# ACSDT5Y2012                             ACS 5-Year Detailed Tables
# ACSDT5Y2013                             ACS 5-Year Detailed Tables
# ACSDT5Y2014                             ACS 5-Year Detailed Tables
# ACSDT5Y2015                             ACS 5-Year Detailed Tables
# ACSDT5Y2016                             ACS 5-Year Detailed Tables
# ACSDT5Y2017                             ACS 5-Year Detailed Tables
# ACSDT5Y2018      American Community Survey: 5-Year Estimates: D...
# ACSDT5Y2019      American Community Survey: 5-Year Estimates: D...
# ACSDT5Y2020      American Community Survey: 5-Year Estimates: D...
# ACSDT5Y2021      American Community Survey: 5-Year Estimates: D...
# ACSDT5Y2022      American Community Survey: 5-Year Estimates: D...
# ACSDT5Y2023                             ACS 5-Year Detailed Tables
# ACSDT5YAIAN2010  American Community Survey: 5-Year Estimates: A...
# ACSDT5YAIAN2015                    ACS 5-Year AIAN Detailed Tables
# ACSDT5YAIAN2021  American Community Survey: 5-Year Estimates: A...
# ACSDT5YSPT2010   American Community Survey: 5-Year Estimates: S...
# ACSDT5YSPT2015   American Community Survey: 5-Year Estimates: S...
# ACSDT5YSPT2021   American Community Survey: 5-Year Estimates: S...
#
#                 c_isAvailable c_isCube c_isMicrodata  \
# ACSDT5Y2009              True     True           NaN
# ACSDT5Y2010              True     True           NaN
# ACSDT5Y2011              True     True           NaN
# ACSDT5Y2012              True     True           NaN
# ACSDT5Y2013              True     True           NaN
# ACSDT5Y2014              True     True           NaN
# ACSDT5Y2015              True     True           NaN
# ACSDT5Y2016              True     True           NaN
# ACSDT5Y2017              True     True           NaN
# ACSDT5Y2018              True     True           NaN
# ACSDT5Y2019              True     True           NaN
# ACSDT5Y2020              True     True           NaN
# ACSDT5Y2021              True     True           NaN
# ACSDT5Y2022              True     True           NaN
# ACSDT5Y2023              True     True           NaN
# ACSDT5YAIAN2010          True     True           NaN
# ACSDT5YAIAN2015          True     True           NaN
# ACSDT5YAIAN2021          True     True           NaN
# ACSDT5YSPT2010           True     True           NaN
# ACSDT5YSPT2015           True     True           NaN
# ACSDT5YSPT2021           True     True           NaN
#
#                                c_documentationLink          c_dataset vintage
# ACSDT5Y2009      https://www.census.gov/developer/        (acs, acs5)  2009.0
# ACSDT5Y2010      https://www.census.gov/developer/        (acs, acs5)  2010.0
# ACSDT5Y2011      https://www.census.gov/developer/        (acs, acs5)  2011.0
# ACSDT5Y2012      https://www.census.gov/developer/        (acs, acs5)  2012.0
# ACSDT5Y2013      https://www.census.gov/developer/        (acs, acs5)  2013.0
# ACSDT5Y2014      https://www.census.gov/developer/        (acs, acs5)  2014.0
# ACSDT5Y2015      https://www.census.gov/developer/        (acs, acs5)  2015.0
# ACSDT5Y2016      https://www.census.gov/developer/        (acs, acs5)  2016.0
# ACSDT5Y2017      https://www.census.gov/developer/        (acs, acs5)  2017.0
# ACSDT5Y2018      https://www.census.gov/developer/        (acs, acs5)  2018.0
# ACSDT5Y2019      https://www.census.gov/developer/        (acs, acs5)  2019.0
# ACSDT5Y2020      https://www.census.gov/developer/        (acs, acs5)  2020.0
# ACSDT5Y2021      https://www.census.gov/developer/        (acs, acs5)  2021.0
# ACSDT5Y2022      https://www.census.gov/developer/        (acs, acs5)  2022.0
# ACSDT5Y2023      https://www.census.gov/developer/        (acs, acs5)  2023.0
# ACSDT5YAIAN2010  https://www.census.gov/developer/  (acs, acs5, aian)  2010.0
# ACSDT5YAIAN2015  https://www.census.gov/developer/  (acs, acs5, aian)  2015.0
# ACSDT5YAIAN2021  https://www.census.gov/developer/  (acs, acs5, aian)  2021.0
# ACSDT5YSPT2010   https://www.census.gov/developer/   (acs, acs5, spt)  2010.0
# ACSDT5YSPT2015   https://www.census.gov/developer/   (acs, acs5, spt)  2015.0
# ACSDT5YSPT2021   https://www.census.gov/developer/   (acs, acs5, spt)  2021.0
#
# [21 rows x 23 columns]

# %%
#| echo: false
#| code-fold: true
#| include: false

cenpy.explorer.explain("ACSDT5Y2023")
acs = cenpy.remote.APIConnection('ACSDT5Y2023')

# %%
#| echo: false
#| code-fold: true
#| include: false

acs.varslike(
    pattern="B19019_001E",
    by="attributes",
).sort_index()
# Out:
#                         label  \
# B19019_001E  Estimate!!Total:
#
#                                                        concept predicateType  \
# B19019_001E  Median Household Income in the Past 12 Months ...           int
#
#               group limit predicateOnly hasGeoCollectionSupport  \
# B19019_001E  B19019     0           NaN                     NaN
#
#                                         attributes required
# B19019_001E  B19019_001EA,B19019_001M,B19019_001MA      NaN

# %%
#| echo: false
#| code-fold: true
#| include: false

acs_variables = [
    "NAME",
    "GEO_ID",
    "B19019_001E", # Total Median Household Income
    "B06009_001E", # Educational Attainment- Total
    "B06009_002E", # Educational Attainment- Less than high school graduate
    "B06009_003E", # Educational Attainment- High school graduate (equivalent)
    "B06009_004E", # Educational Attainment- Some college or associate's degree
    "B06009_005E", # Educational Attainment- Bachelor's degree or higher
    "B01003_001E", # Total Population
    "B23025_001E", # Total Population above 16
    "B23025_002E", # Labor Force- Total
    "B23025_005E", # Labour Force- Unemployed
    "B17020_001E", # Population for whom poverty is determined
    "B17020_002E", # Population below poverty level
]

#1. Median Household Income [x]
#2. Education Levels [x]
#3. Unemployment rate [x]
#4. Labour force participation rate [x]
#5. Population [x]
#6. Poverty rate [x]

# %%
#| echo: false
#| code-fold: true
#| include: false

# Filter out the data for state
USA_acs_data = acs.query(
    cols=acs_variables,
    geo_unit="state:*",
)

USA_acs_data.head()
# Out:
#          NAME       GEO_ID B19019_001E B06009_001E B06009_002E B06009_003E  \
# 0     Alabama  0400000US01       62027     3448302      409381     1046374
# 1      Alaska  0400000US02       89336      487903       31854      141206
# 2     Arizona  0400000US04       76872     4990633      544528     1171693
# 3    Arkansas  0400000US05       58773     2043779      233857      702778
# 4  California  0400000US06       96334    26941198     4149146     5496195
#
#   B06009_004E B06009_005E B01003_001E B23025_001E B23025_002E B23025_005E  \
# 0     1035466      584986     5054253     4056609     2358667      112849
# 1      162411       95793      733971      574021      380935       20644
# 2     1646950      999535     7268175     5862117     3547314      182184
# 3      593923      324625     3032651     2409758     1405609       71269
# 4     7461496     6035609    39242785    31545603    20144078     1282259
#
#   B17020_001E B17020_002E state
# 0     4913932      768185    01
# 1      716703       72978    02
# 2     7109159      907125    04
# 3     2944742      471783    05
# 4    38529452     4610600    06

# %%
#| echo: false
#| code-fold: true
#| include: false

for variable in acs_variables:
    # Convert all variables EXCEPT for NAME
    if variable not in ("NAME", "GEO_ID"):
        USA_acs_data[variable] = USA_acs_data[variable].astype(float)

# %%
#| echo: false
#| code-fold: true
#| include: false

USA_acs_data = USA_acs_data.rename(
    columns={
        "B19019_001E": "MedHHInc", # Total Median Household Income
        "B06009_001E": "EducTotal", # Educational Attainment- Total
        "B06009_002E": "EducBelowHighSch", # Educational Attainment- Less than high school graduate
        "B06009_003E": "EducHighSch", # Educational Attainment- High school graduate (equivalent)
        "B06009_004E": "EducAssoc", # Educational Attainment- Some college or associate's degree
        "B06009_005E": "EducBach", # Educational Attainment- Bachelor's degree or higher
        "B01003_001E": "TotalPop", # Total Population
        "B23025_001E": "TotalPop16", # Total Population above 16
        "B23025_002E": "LabForTotal", # Labor Force- Total
        "B23025_005E": "Unemployed", # Labour Force- Unemployed
        "B17020_001E": "PopPovertyDetermined", # Population for whom poverty is determined
        "B17020_002E": "PovertyPop", # Population below poverty level
    }
)

# %%
#| echo: false
#| code-fold: true
#| include: false

USA_acs_data['PctBach'] = USA_acs_data['EducBach']/USA_acs_data['EducTotal']
USA_acs_data['PovertyRate'] = USA_acs_data['PovertyPop']/USA_acs_data['PopPovertyDetermined']
USA_acs_data['UnemploymentRate'] = USA_acs_data['Unemployed']/USA_acs_data['LabForTotal']
USA_acs_data['LabForParticipationRate'] = USA_acs_data['LabForTotal']/USA_acs_data['TotalPop16']

#Remove Puerto Rico
USA_acs_data = USA_acs_data[USA_acs_data['NAME'] != 'Puerto Rico']

# %%
#| echo: false
#| code-fold: true
#| include: false

cenpy.explorer.explain("ITMONTHLYEXPORTSSTATENAICS")
US_export = cenpy.remote.APIConnection('ITMONTHLYEXPORTSSTATENAICS')

# %%
#| echo: false
#| code-fold: true
#| include: false

US_export.variables
# Out:
#                                                           label  \
# for                                Census API FIPS 'for' clause
# in                                  Census API FIPS 'in' clause
# ucgid                Uniform Census Geography Identifier clause
# time                                   ISO-8601 Date/Time value
# CNT_WGT_YR    Year-to-Date Containerized Vessel Shipping Weight
# MONTH                                                     Month
# SUMMARY_LVL                Detail or Country Grouping indicator
# COMM_LVL      4-character aggregation levels for commodity code
# CNT_VAL_MO                           Containerized Vessel Value
# AIR_WGT_MO                                  Air Shipping Weight
# VES_WGT_MO                               Vessel Shipping Weight
# USITC                        USITC Standard Countries and Areas
# NAICS                      NAICS-based International Trade code
# CNT_VAL_YR              Year-to-Date Containerized Vessel Value
# GEOCOMP                                        GEO_ID Component
# NAICS_LDESC   150-character NAICS-based International Trade ...
# YEAR                                                       Year
# SUMMARY_LVL2                         Variables being summarized
# AIR_WGT_YR                     Year-to-Date Air Shipping Weight
# CNT_WGT_MO                 Containerized Vessel Shipping Weight
# VES_WGT_YR                  Year-to-Date Vessel Shipping Weight
# USITCHISTORY      USITC Standard Historical Countries and Areas
# WORLD                                                     World
# USITCREG                   USITC Standard International Regions
# ALL_VAL_MO                                          Total Value
# AIR_VAL_MO                                            Air Value
# ALL_VAL_YR                             Year-to-Date Total Value
# US_STATE                            State of Origin of Movement
# GEO_ID                               Geographic identifier code
# SUMLEVEL                                     Summary Level code
# LAST_UPDATE                                 Date of Last Update
# NAICS_SDESC   50-character NAICS-based International Trade C...
# VES_VAL_MO                                         Vessel Value
# CTY_CODE                                           Country Code
# VES_VAL_YR                            Year-to-Date Vessel Value
# AIR_VAL_YR                               Year-to-Date Air Value
#
#                                                         concept predicateType  \
# for                          Census API Geography Specification      fips-for
# in                           Census API Geography Specification       fips-in
# ucgid                        Census API Geography Specification         ucgid
# time                         Census API Date/Time Specification      datetime
# CNT_WGT_YR    Monthly Exports by State of Origin and NAICS code           int
# MONTH                                                       NaN        string
# SUMMARY_LVL                                                 NaN        string
# COMM_LVL                                                    NaN        string
# CNT_VAL_MO    Monthly Exports by State of Origin and NAICS code           int
# AIR_WGT_MO    Monthly Exports by State of Origin and NAICS code           int
# VES_WGT_MO    Monthly Exports by State of Origin and NAICS code           int
# USITC                                                       NaN           NaN
# NAICS         Monthly Exports by State of Origin and NAICS code        string
# CNT_VAL_YR    Monthly Exports by State of Origin and NAICS code           int
# GEOCOMP                                                     NaN        string
# NAICS_LDESC                                                 NaN        string
# YEAR                                                        NaN        string
# SUMMARY_LVL2                                                NaN        string
# AIR_WGT_YR    Monthly Exports by State of Origin and NAICS code           int
# CNT_WGT_MO    Monthly Exports by State of Origin and NAICS code           int
# VES_WGT_YR    Monthly Exports by State of Origin and NAICS code           int
# USITCHISTORY                                                NaN           NaN
# WORLD                                                       NaN           NaN
# USITCREG                                                    NaN           NaN
# ALL_VAL_MO    Monthly Exports by State of Origin and NAICS code           int
# AIR_VAL_MO    Monthly Exports by State of Origin and NAICS code           int
# ALL_VAL_YR    Monthly Exports by State of Origin and NAICS code           int
# US_STATE      Monthly Exports by State of Origin and NAICS code        string
# GEO_ID        Monthly Exports by State of Origin and NAICS code        string
# SUMLEVEL                                                    NaN        string
# LAST_UPDATE                                                 NaN        string
# NAICS_SDESC                                                 NaN        string
# VES_VAL_MO    Monthly Exports by State of Origin and NAICS code           int
# CTY_CODE                                                    NaN        string
# VES_VAL_YR    Monthly Exports by State of Origin and NAICS code           int
# AIR_VAL_YR    Monthly Exports by State of Origin and NAICS code           int
#
#                              group limit predicateOnly  \
# for                            N/A     0          True
# in                             N/A     0          True
# ucgid                          N/A     0          True
# time                           N/A     0          True
# CNT_WGT_YR    IT00EXPORTSTATENAICS     0           NaN
# MONTH                          N/A     0           NaN
# SUMMARY_LVL                    N/A     0           NaN
# COMM_LVL                       N/A     0           NaN
# CNT_VAL_MO    IT00EXPORTSTATENAICS     0           NaN
# AIR_WGT_MO    IT00EXPORTSTATENAICS     0           NaN
# VES_WGT_MO    IT00EXPORTSTATENAICS     0           NaN
# USITC                          N/A     0           NaN
# NAICS         IT00EXPORTSTATENAICS     0           NaN
# CNT_VAL_YR    IT00EXPORTSTATENAICS     0           NaN
# GEOCOMP                        N/A     0           NaN
# NAICS_LDESC                    N/A     0           NaN
# YEAR                           N/A     0           NaN
# SUMMARY_LVL2                   N/A     0           NaN
# AIR_WGT_YR    IT00EXPORTSTATENAICS     0           NaN
# CNT_WGT_MO    IT00EXPORTSTATENAICS     0           NaN
# VES_WGT_YR    IT00EXPORTSTATENAICS     0           NaN
# USITCHISTORY                   N/A     0           NaN
# WORLD                          N/A     0           NaN
# USITCREG                       N/A     0           NaN
# ALL_VAL_MO    IT00EXPORTSTATENAICS     0           NaN
# AIR_VAL_MO    IT00EXPORTSTATENAICS     0           NaN
# ALL_VAL_YR    IT00EXPORTSTATENAICS     0           NaN
# US_STATE      IT00EXPORTSTATENAICS     0           NaN
# GEO_ID        IT00EXPORTSTATENAICS     0           NaN
# SUMLEVEL                       N/A     0           NaN
# LAST_UPDATE                    N/A     0           NaN
# NAICS_SDESC                    N/A     0           NaN
# VES_VAL_MO    IT00EXPORTSTATENAICS     0           NaN
# CTY_CODE                       N/A     0           NaN
# VES_VAL_YR    IT00EXPORTSTATENAICS     0           NaN
# AIR_VAL_YR    IT00EXPORTSTATENAICS     0           NaN
#
#              hasGeoCollectionSupport           required  \
# for                              NaN                NaN
# in                               NaN                NaN
# ucgid                           True                NaN
# time                             NaN               true
# CNT_WGT_YR                       NaN                NaN
# MONTH                            NaN                NaN
# SUMMARY_LVL                      NaN                NaN
# COMM_LVL                         NaN                NaN
# CNT_VAL_MO                       NaN                NaN
# AIR_WGT_MO                       NaN                NaN
# VES_WGT_MO                       NaN                NaN
# USITC                            NaN                NaN
# NAICS                            NaN  default displayed
# CNT_VAL_YR                       NaN                NaN
# GEOCOMP                          NaN                NaN
# NAICS_LDESC                      NaN                NaN
# YEAR                             NaN                NaN
# SUMMARY_LVL2                     NaN                NaN
# AIR_WGT_YR                       NaN                NaN
# CNT_WGT_MO                       NaN                NaN
# VES_WGT_YR                       NaN                NaN
# USITCHISTORY                     NaN                NaN
# WORLD                            NaN                NaN
# USITCREG                         NaN                NaN
# ALL_VAL_MO                       NaN                NaN
# AIR_VAL_MO                       NaN                NaN
# ALL_VAL_YR                       NaN                NaN
# US_STATE                         NaN                NaN
# GEO_ID                           NaN                NaN
# SUMLEVEL                         NaN                NaN
# LAST_UPDATE                      NaN                NaN
# NAICS_SDESC                      NaN                NaN
# VES_VAL_MO                       NaN                NaN
# CTY_CODE                         NaN                NaN
# VES_VAL_YR                       NaN                NaN
# AIR_VAL_YR                       NaN                NaN
#
#                                    datetime      attributes  \
# for                                     NaN             NaN
# in                                      NaN             NaN
# ucgid                                   NaN             NaN
# time          {'year': True, 'month': True}             NaN
# CNT_WGT_YR                              NaN             NaN
# MONTH                                   NaN             NaN
# SUMMARY_LVL                             NaN             NaN
# COMM_LVL                                NaN  COMM_LVL_LABEL
# CNT_VAL_MO                              NaN             NaN
# AIR_WGT_MO                              NaN             NaN
# VES_WGT_MO                              NaN             NaN
# USITC                                   NaN             NaN
# NAICS                                   NaN     NAICS_LABEL
# CNT_VAL_YR                              NaN             NaN
# GEOCOMP                                 NaN             NaN
# NAICS_LDESC                             NaN             NaN
# YEAR                                    NaN             NaN
# SUMMARY_LVL2                            NaN             NaN
# AIR_WGT_YR                              NaN             NaN
# CNT_WGT_MO                              NaN             NaN
# VES_WGT_YR                              NaN             NaN
# USITCHISTORY                            NaN             NaN
# WORLD                                   NaN             NaN
# USITCREG                                NaN             NaN
# ALL_VAL_MO                              NaN             NaN
# AIR_VAL_MO                              NaN             NaN
# ALL_VAL_YR                              NaN             NaN
# US_STATE                                NaN  US_STATE_LABEL
# GEO_ID                                  NaN            NAME
# SUMLEVEL                                NaN             NaN
# LAST_UPDATE                             NaN             NaN
# NAICS_SDESC                             NaN             NaN
# VES_VAL_MO                              NaN             NaN
# CTY_CODE                                NaN        CTY_NAME
# VES_VAL_YR                              NaN             NaN
# AIR_VAL_YR                              NaN             NaN
#
#                                                          values
# for                                                         NaN
# in                                                          NaN
# ucgid                                                       NaN
# time                                                        NaN
# CNT_WGT_YR                                                  NaN
# MONTH                                                       NaN
# SUMMARY_LVL                                                 NaN
# COMM_LVL                                                    NaN
# CNT_VAL_MO                                                  NaN
# AIR_WGT_MO                                                  NaN
# VES_WGT_MO                                                  NaN
# USITC                                                       NaN
# NAICS         {'item': {'-': 'Total For All North American I...
# CNT_VAL_YR                                                  NaN
# GEOCOMP                                                     NaN
# NAICS_LDESC                                                 NaN
# YEAR                                                        NaN
# SUMMARY_LVL2                                                NaN
# AIR_WGT_YR                                                  NaN
# CNT_WGT_MO                                                  NaN
# VES_WGT_YR                                                  NaN
# USITCHISTORY                                                NaN
# WORLD                                                       NaN
# USITCREG                                                    NaN
# ALL_VAL_MO                                                  NaN
# AIR_VAL_MO                                                  NaN
# ALL_VAL_YR                                                  NaN
# US_STATE                                                    NaN
# GEO_ID                                                      NaN
# SUMLEVEL                                                    NaN
# LAST_UPDATE                                                 NaN
# NAICS_SDESC                                                 NaN
# VES_VAL_MO                                                  NaN
# CTY_CODE                                                    NaN
# VES_VAL_YR                                                  NaN
# AIR_VAL_YR                                                  NaN

# %%
#| echo: false
#| code-fold: true
#| include: false

US_export.geographies['fips']
# Out:
#                                             name geoLevelDisplay referenceDate
# 0                                          world             W01    2022-01-01
# 1           usitc standard international regions             W04    2022-01-01
# 2             usitc standard countries and areas             W16    2022-01-01
# 3  usitc standard historical countries and areas             W20    2022-01-01

# %%
#| echo: false
#| code-fold: true
#| include: false

US_export_data = US_export.query(
    cols=["US_STATE", "GEO_ID","YEAR","MONTH","ALL_VAL_YR"],
    geo_unit="world:*",
    )

for variable in ["YEAR","MONTH","ALL_VAL_YR"]:
    US_export_data[variable] = US_export_data[variable].astype(float)

US_export_data
# Out:
#      US_STATE     GEO_ID    YEAR  MONTH    ALL_VAL_YR world
# 0           -  W0100Y1WO  2013.0    1.0  1.230319e+11     1
# 1          AK  W0100Y1WO  2013.0    1.0  7.526427e+07     1
# 2          AL  W0100Y1WO  2013.0    1.0  1.300844e+09     1
# 3          AR  W0100Y1WO  2013.0    1.0  4.963303e+08     1
# 4          AZ  W0100Y1WO  2013.0    1.0  1.510832e+09     1
# ...       ...        ...     ...    ...           ...   ...
# 9785       WA  W0100Y1WO  2024.0   10.0  4.816321e+10     1
# 9786       WI  W0100Y1WO  2024.0   10.0  2.333412e+10     1
# 9787       XX  W0100Y1WO  2024.0   10.0  6.910604e+10     1
# 9788       WV  W0100Y1WO  2024.0   10.0  4.155562e+09     1
# 9789       WY  W0100Y1WO  2024.0   10.0  1.712623e+09     1
#
# [9790 rows x 6 columns]

# %%
#| echo: false
#| code-fold: true
#| include: false

# Filter data for December 2023
US_export_2023 = US_export_data[(US_export_data['YEAR'] == 2023) & (US_export_data['MONTH'] == 12)]

# %%
#| echo: false
#| code-fold: true
#| include: false

cenpy.explorer.explain("ITMONTHLYIMPORTSSTATENAICS")
US_import = cenpy.remote.APIConnection('ITMONTHLYIMPORTSSTATENAICS')

# %%
#| echo: false
#| code-fold: true
#| include: false

US_import.variables
# Out:
#                                                           label  \
# for                                Census API FIPS 'for' clause
# in                                  Census API FIPS 'in' clause
# ucgid                Uniform Census Geography Identifier clause
# time                                   ISO-8601 Date/Time value
# CNT_WGT_YR    Year-to-Date Containerized Vessel Shipping Weight
# MONTH                                                     Month
# SUMMARY_LVL                Detail or Country Grouping indicator
# COMM_LVL      4-character aggregation levels for commodity code
# CON_VAL_MO                 Imports for Consumption, Total Value
# CNT_VAL_MO                           Containerized Vessel Value
# VES_WGT_MO                               Vessel Shipping Weight
# AIR_WGT_MO                                  Air Shipping Weight
# USITC                        USITC Standard Countries and Areas
# NAICS                      NAICS-based International Trade Code
# CON_VAL_YR    Year-to-Date Imports for Consumption, Total Value
# CNT_VAL_YR              Year-to-Date Containerized Vessel Value
# GEOCOMP                                        GEO_ID Component
# GEN_VAL_YR            Year-to-Date General Imports, Total Value
# NAICS_LDESC   150-character NAICS-based International Trade ...
# YEAR                                                       Year
# SUMMARY_LVL2                         Variables being summarized
# AIR_WGT_YR                     Year-to-Date Air Shipping Weight
# CNT_WGT_MO                 Containerized Vessel Shipping Weight
# VES_WGT_YR                  Year-to-Date Vessel Shipping Weight
# USITCHISTORY      USITC Standard Historical Countries and Areas
# GEN_VAL_MO                         General Imports, Total Value
# WORLD                                                     World
# USITCREG                   USITC Standard International Regions
# AIR_VAL_MO                                            Air Value
# US_STATE                                   State of Destination
# GEO_ID                               Geographic identifier code
# SUMLEVEL                                     Summary Level code
# LAST_UPDATE                                 Date of Last Update
# NAICS_SDESC   50-character NAICS-based International Trade C...
# VES_VAL_MO                                         Vessel Value
# CTY_CODE                                           Country Code
# VES_VAL_YR                            Year-to-Date Vessel Value
# AIR_VAL_YR                               Year-to-Date Air Value
#
#                                          concept predicateType  \
# for           Census API Geography Specification      fips-for
# in            Census API Geography Specification       fips-in
# ucgid         Census API Geography Specification         ucgid
# time          Census API Date/Time Specification      datetime
# CNT_WGT_YR    Monthly Imports by State and NAICS           int
# MONTH                                        NaN        string
# SUMMARY_LVL                                  NaN        string
# COMM_LVL                                     NaN        string
# CON_VAL_MO    Monthly Imports by State and NAICS           int
# CNT_VAL_MO    Monthly Imports by State and NAICS           int
# VES_WGT_MO    Monthly Imports by State and NAICS           int
# AIR_WGT_MO    Monthly Imports by State and NAICS           int
# USITC                                        NaN           NaN
# NAICS         Monthly Imports by State and NAICS        string
# CON_VAL_YR    Monthly Imports by State and NAICS           int
# CNT_VAL_YR    Monthly Imports by State and NAICS           int
# GEOCOMP                                      NaN        string
# GEN_VAL_YR    Monthly Imports by State and NAICS           int
# NAICS_LDESC                                  NaN        string
# YEAR                                         NaN        string
# SUMMARY_LVL2                                 NaN        string
# AIR_WGT_YR    Monthly Imports by State and NAICS           int
# CNT_WGT_MO    Monthly Imports by State and NAICS           int
# VES_WGT_YR    Monthly Imports by State and NAICS           int
# USITCHISTORY                                 NaN           NaN
# GEN_VAL_MO    Monthly Imports by State and NAICS           int
# WORLD                                        NaN           NaN
# USITCREG                                     NaN           NaN
# AIR_VAL_MO    Monthly Imports by State and NAICS           int
# US_STATE      Monthly Imports by State and NAICS        string
# GEO_ID        Monthly Imports by State and NAICS        string
# SUMLEVEL                                     NaN        string
# LAST_UPDATE                                  NaN        string
# NAICS_SDESC                                  NaN        string
# VES_VAL_MO    Monthly Imports by State and NAICS           int
# CTY_CODE                                     NaN        string
# VES_VAL_YR    Monthly Imports by State and NAICS           int
# AIR_VAL_YR    Monthly Imports by State and NAICS           int
#
#                               group limit predicateOnly  \
# for                             N/A     0          True
# in                              N/A     0          True
# ucgid                           N/A     0          True
# time                            N/A     0          True
# CNT_WGT_YR    IT00IMPORTSSTATENAICS     0           NaN
# MONTH                           N/A     0           NaN
# SUMMARY_LVL                     N/A     0           NaN
# COMM_LVL                        N/A     0           NaN
# CON_VAL_MO    IT00IMPORTSSTATENAICS     0           NaN
# CNT_VAL_MO    IT00IMPORTSSTATENAICS     0           NaN
# VES_WGT_MO    IT00IMPORTSSTATENAICS     0           NaN
# AIR_WGT_MO    IT00IMPORTSSTATENAICS     0           NaN
# USITC                           N/A     0           NaN
# NAICS         IT00IMPORTSSTATENAICS     0           NaN
# CON_VAL_YR    IT00IMPORTSSTATENAICS     0           NaN
# CNT_VAL_YR    IT00IMPORTSSTATENAICS     0           NaN
# GEOCOMP                         N/A     0           NaN
# GEN_VAL_YR    IT00IMPORTSSTATENAICS     0           NaN
# NAICS_LDESC                     N/A     0           NaN
# YEAR                            N/A     0           NaN
# SUMMARY_LVL2                    N/A     0           NaN
# AIR_WGT_YR    IT00IMPORTSSTATENAICS     0           NaN
# CNT_WGT_MO    IT00IMPORTSSTATENAICS     0           NaN
# VES_WGT_YR    IT00IMPORTSSTATENAICS     0           NaN
# USITCHISTORY                    N/A     0           NaN
# GEN_VAL_MO    IT00IMPORTSSTATENAICS     0           NaN
# WORLD                           N/A     0           NaN
# USITCREG                        N/A     0           NaN
# AIR_VAL_MO    IT00IMPORTSSTATENAICS     0           NaN
# US_STATE      IT00IMPORTSSTATENAICS     0           NaN
# GEO_ID        IT00IMPORTSSTATENAICS     0           NaN
# SUMLEVEL                        N/A     0           NaN
# LAST_UPDATE                     N/A     0           NaN
# NAICS_SDESC                     N/A     0           NaN
# VES_VAL_MO    IT00IMPORTSSTATENAICS     0           NaN
# CTY_CODE                        N/A     0           NaN
# VES_VAL_YR    IT00IMPORTSSTATENAICS     0           NaN
# AIR_VAL_YR    IT00IMPORTSSTATENAICS     0           NaN
#
#              hasGeoCollectionSupport           required  \
# for                              NaN                NaN
# in                               NaN                NaN
# ucgid                           True                NaN
# time                             NaN               true
# CNT_WGT_YR                       NaN                NaN
# MONTH                            NaN                NaN
# SUMMARY_LVL                      NaN                NaN
# COMM_LVL                         NaN                NaN
# CON_VAL_MO                       NaN                NaN
# CNT_VAL_MO                       NaN                NaN
# VES_WGT_MO                       NaN                NaN
# AIR_WGT_MO                       NaN                NaN
# USITC                            NaN                NaN
# NAICS                            NaN  default displayed
# CON_VAL_YR                       NaN                NaN
# CNT_VAL_YR                       NaN                NaN
# GEOCOMP                          NaN                NaN
# GEN_VAL_YR                       NaN                NaN
# NAICS_LDESC                      NaN                NaN
# YEAR                             NaN                NaN
# SUMMARY_LVL2                     NaN                NaN
# AIR_WGT_YR                       NaN                NaN
# CNT_WGT_MO                       NaN                NaN
# VES_WGT_YR                       NaN                NaN
# USITCHISTORY                     NaN                NaN
# GEN_VAL_MO                       NaN                NaN
# WORLD                            NaN                NaN
# USITCREG                         NaN                NaN
# AIR_VAL_MO                       NaN                NaN
# US_STATE                         NaN                NaN
# GEO_ID                           NaN                NaN
# SUMLEVEL                         NaN                NaN
# LAST_UPDATE                      NaN                NaN
# NAICS_SDESC                      NaN                NaN
# VES_VAL_MO                       NaN                NaN
# CTY_CODE                         NaN                NaN
# VES_VAL_YR                       NaN                NaN
# AIR_VAL_YR                       NaN                NaN
#
#                                    datetime      attributes  \
# for                                     NaN             NaN
# in                                      NaN             NaN
# ucgid                                   NaN             NaN
# time          {'month': True, 'year': True}             NaN
# CNT_WGT_YR                              NaN             NaN
# MONTH                                   NaN             NaN
# SUMMARY_LVL                             NaN             NaN
# COMM_LVL                                NaN  COMM_LVL_LABEL
# CON_VAL_MO                              NaN             NaN
# CNT_VAL_MO                              NaN             NaN
# VES_WGT_MO                              NaN             NaN
# AIR_WGT_MO                              NaN             NaN
# USITC                                   NaN             NaN
# NAICS                                   NaN     NAICS_LABEL
# CON_VAL_YR                              NaN             NaN
# CNT_VAL_YR                              NaN             NaN
# GEOCOMP                                 NaN             NaN
# GEN_VAL_YR                              NaN             NaN
# NAICS_LDESC                             NaN             NaN
# YEAR                                    NaN             NaN
# SUMMARY_LVL2                            NaN             NaN
# AIR_WGT_YR                              NaN             NaN
# CNT_WGT_MO                              NaN             NaN
# VES_WGT_YR                              NaN             NaN
# USITCHISTORY                            NaN             NaN
# GEN_VAL_MO                              NaN             NaN
# WORLD                                   NaN             NaN
# USITCREG                                NaN             NaN
# AIR_VAL_MO                              NaN             NaN
# US_STATE                                NaN  US_STATE_LABEL
# GEO_ID                                  NaN            NAME
# SUMLEVEL                                NaN             NaN
# LAST_UPDATE                             NaN             NaN
# NAICS_SDESC                             NaN             NaN
# VES_VAL_MO                              NaN             NaN
# CTY_CODE                                NaN        CTY_NAME
# VES_VAL_YR                              NaN             NaN
# AIR_VAL_YR                              NaN             NaN
#
#                                                          values
# for                                                         NaN
# in                                                          NaN
# ucgid                                                       NaN
# time                                                        NaN
# CNT_WGT_YR                                                  NaN
# MONTH                                                       NaN
# SUMMARY_LVL                                                 NaN
# COMM_LVL                                                    NaN
# CON_VAL_MO                                                  NaN
# CNT_VAL_MO                                                  NaN
# VES_WGT_MO                                                  NaN
# AIR_WGT_MO                                                  NaN
# USITC                                                       NaN
# NAICS         {'item': {'-': 'Total For All North American I...
# CON_VAL_YR                                                  NaN
# CNT_VAL_YR                                                  NaN
# GEOCOMP                                                     NaN
# GEN_VAL_YR                                                  NaN
# NAICS_LDESC                                                 NaN
# YEAR                                                        NaN
# SUMMARY_LVL2                                                NaN
# AIR_WGT_YR                                                  NaN
# CNT_WGT_MO                                                  NaN
# VES_WGT_YR                                                  NaN
# USITCHISTORY                                                NaN
# GEN_VAL_MO                                                  NaN
# WORLD                                                       NaN
# USITCREG                                                    NaN
# AIR_VAL_MO                                                  NaN
# US_STATE                                                    NaN
# GEO_ID                                                      NaN
# SUMLEVEL                                                    NaN
# LAST_UPDATE                                                 NaN
# NAICS_SDESC                                                 NaN
# VES_VAL_MO                                                  NaN
# CTY_CODE                                                    NaN
# VES_VAL_YR                                                  NaN
# AIR_VAL_YR                                                  NaN

# %%
#| echo: false
#| code-fold: true
#| include: false

US_import_data = US_import.query(
    cols=["US_STATE", "GEO_ID","YEAR","MONTH","GEN_VAL_YR"],
    geo_unit="world:*",
    )

for variable in ["YEAR","MONTH","GEN_VAL_YR"]:
    US_import_data[variable] = US_import_data[variable].astype(float)

US_import_data
# Out:
#      US_STATE     GEO_ID    YEAR  MONTH    GEN_VAL_YR world
# 0           -  W0100Y1WO  2013.0    1.0  1.851686e+11     1
# 1          AK  W0100Y1WO  2013.0    1.0  7.511713e+07     1
# 2          AL  W0100Y1WO  2013.0    1.0  1.525358e+09     1
# 3          AR  W0100Y1WO  2013.0    1.0  6.097465e+08     1
# 4          AZ  W0100Y1WO  2013.0    1.0  1.782983e+09     1
# ...       ...        ...     ...    ...           ...   ...
# 9785       WA  W0100Y1WO  2024.0   10.0  5.254540e+10     1
# 9786       WI  W0100Y1WO  2024.0   10.0  3.284204e+10     1
# 9787       WV  W0100Y1WO  2024.0   10.0  4.158808e+09     1
# 9788       WY  W0100Y1WO  2024.0   10.0  1.113063e+09     1
# 9789       XX  W0100Y1WO  2024.0   10.0  2.036682e+10     1
#
# [9790 rows x 6 columns]

# %%
#| echo: false
#| code-fold: true
#| include: false

# Filter data for December 2023
US_import_2023 = US_import_data[(US_import_data['YEAR'] == 2023) & (US_import_data['MONTH'] == 12)]

# %%
#| echo: false
#| code-fold: true
#| include: false

# Join export and import data
US_netexport_2023 = US_export_2023.merge(US_import_2023[['US_STATE', 'GEN_VAL_YR']], on='US_STATE', how='left')

# Net export
US_netexport_2023["netexport"] = US_netexport_2023["ALL_VAL_YR"]-US_netexport_2023["GEN_VAL_YR"]

# %%
#| echo: false
#| code-fold: true
#| include: false

# Create new column with states name
state_names = {
    'AL': 'Alabama', 'AK': 'Alaska', 'AZ': 'Arizona', 'AR': 'Arkansas', 'CA': 'California',
    'CO': 'Colorado', 'CT': 'Connecticut', 'DE': 'Delaware', 'FL': 'Florida', 'GA': 'Georgia',
    'HI': 'Hawaii', 'ID': 'Idaho', 'IL': 'Illinois', 'IN': 'Indiana', 'IA': 'Iowa',
    'KS': 'Kansas', 'KY': 'Kentucky', 'LA': 'Louisiana', 'ME': 'Maine', 'MD': 'Maryland',
    'MA': 'Massachusetts', 'MI': 'Michigan', 'MN': 'Minnesota', 'MS': 'Mississippi', 'MO': 'Missouri',
    'MT': 'Montana', 'NE': 'Nebraska', 'NV': 'Nevada', 'NH': 'New Hampshire', 'NJ': 'New Jersey',
    'NM': 'New Mexico', 'NY': 'New York', 'NC': 'North Carolina', 'ND': 'North Dakota', 'OH': 'Ohio',
    'OK': 'Oklahoma', 'OR': 'Oregon', 'PA': 'Pennsylvania', 'RI': 'Rhode Island', 'SC': 'South Carolina',
    'SD': 'South Dakota', 'TN': 'Tennessee', 'TX': 'Texas', 'UT': 'Utah', 'VT': 'Vermont',
    'VA': 'Virginia', 'WA': 'Washington', 'WV': 'West Virginia', 'WI': 'Wisconsin', 'WY': 'Wyoming',
    'DC': 'District of Columbia'
}

US_netexport_2023['STATE_NAME'] = US_netexport_2023['US_STATE'].map(state_names)

# Filter states only
US_netexport_2023 = US_netexport_2023.dropna(subset=['STATE_NAME'])

# %%
#| echo: false
#| code-fold: true
#| include: false

# !pip install beaapi-0.0.2-py3-none-any.whl

import beaapi
# Out:
# Processing c:\users\jiayu\onedrive - penno365\documents\02. musa year 1\musa 5500- geospatial data science in python\quatro_jy\quarto_template\analysis\beaapi-0.0.2-py3-none-any.whl
# Requirement already satisfied: pandas>=1.5 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from beaapi==0.0.2) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from pandas>=1.5->beaapi==0.0.2) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from pandas>=1.5->beaapi==0.0.2) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from pandas>=1.5->beaapi==0.0.2) (1.24.4)
# Requirement already satisfied: six>=1.5 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.5->beaapi==0.0.2) (1.16.0)
# beaapi is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.

# %%
#| echo: false
#| code-fold: true
#| include: false
import config
beakey = config.bea_api_key #API Key

# %%
#| echo: false
#| code-fold: true
#| include: false

# List of data set available
list_of_sets = beaapi.get_data_set_list(beakey)
# List of parameters
list_of_params = beaapi.get_parameter_list(beakey, 'Regional')
# List of parameters values
list_of_param_vals = beaapi.get_parameter_values(beakey, 'Regional', 'LineCode',)
list_of_param_vals
# Out:
#      Key                                               Desc
# 0      1         [CAGDP1] Real Gross Domestic Product (GDP)
# 1      1  [CAGDP11] Contributions to percent change in r...
# 2      1  [CAGDP2] Gross Domestic Product (GDP): All ind...
# 3      1  [CAGDP8] Chain-type quantity indexes for real ...
# 4      1              [CAGDP9] Real GDP: All industry total
# ...   ..                                                ...
# 7191  98  [SAPCE4] Total personal consumption expenditur...
# 7192  99  [SAPCE3] Total personal consumption expenditur...
# 7193  99  [SAPCE4] Total personal consumption expenditur...
# 7194  99  [SAPCE3] Total personal consumption expenditur...
# 7195  99  [SAPCE4] Total personal consumption expenditur...
#
# [7196 rows x 2 columns]

# %%
#| echo: false
#| code-fold: true
#| include: false

bea_tbl = beaapi.get_data(beakey, datasetname='Regional', GeoFips= 'STATE', LineCode= '1', TableName='SAGDP9N', Year='2023')
display(bea_tbl.head(5))
# Out:
#         Code GeoFips        GeoName TimePeriod  \
# 0  SAGDP9N-1   00000  United States       2023
# 1  SAGDP9N-1   01000        Alabama       2023
# 2  SAGDP9N-1   02000         Alaska       2023
# 3  SAGDP9N-1   04000        Arizona       2023
# 4  SAGDP9N-1   05000       Arkansas       2023
#
#                             CL_UNIT  UNIT_MULT   DataValue
# 0  Millions of chained 2017 dollars          6  22671096.0
# 1  Millions of chained 2017 dollars          6    245354.7
# 2  Millions of chained 2017 dollars          6     54059.7
# 3  Millions of chained 2017 dollars          6    422399.6
# 4  Millions of chained 2017 dollars          6    142860.6

# %%
#| echo: false
#| code-fold: true
#| include: false

bea_state_tbl = bea_tbl[bea_tbl['GeoName'].isin(state_names.values())]
bea_state_tbl.rename(columns={'DataValue': 'REALGDP'}, inplace=True)
# Out:
# C:\Users\jiayu\AppData\Local\Temp\ipykernel_22980\1285492324.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bea_state_tbl.rename(columns={'DataValue': 'REALGDP'}, inplace=True)

# %%
#| echo: false
#| code-fold: true
#| include: false

# !pip install sodapy
import pandas as pd
from sodapy import Socrata
# Out:
# Requirement already satisfied: sodapy in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (2.2.0)
# Requirement already satisfied: requests>=2.28.1 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from sodapy) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from requests>=2.28.1->sodapy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from requests>=2.28.1->sodapy) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from requests>=2.28.1->sodapy) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from requests>=2.28.1->sodapy) (2024.7.4)

# %%
#| echo: false
#| code-fold: true
#| include: false

cdc = Socrata("data.cdc.gov", None)
life = cdc.get("it4f-frdc", limit=2000)
life_df = pd.DataFrame.from_records(life)
life_df = life_df[life_df["sex"]=="Total"]
life_df["leb"] = life_df["leb"].astype(float)
life_df.rename(columns={'leb': 'life_expectancy'}, inplace=True)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
#| echo: false
#| code-fold: true
#| include: false

lab_pdt = pd.read_csv('https://raw.githubusercontent.com/JiaYue-Ong/Python-Final-Project/refs/heads/main/labor-productivity.csv')
lab_pdt.head()
# Out:
#             Sector        Area        Basis             Measure  \
# 0  Private nonfarm     Alabama  All workers  Labor productivity
# 1  Private nonfarm      Alaska  All workers  Labor productivity
# 2  Private nonfarm     Arizona  All workers  Labor productivity
# 3  Private nonfarm    Arkansas  All workers  Labor productivity
# 4  Private nonfarm  California  All workers  Labor productivity
#
#               Units    2007    2008     2009     2010     2011  ...     2014  \
# 0  Index (2017=100)  89.822  93.420   97.944  100.873  102.157  ...   99.612
# 1  Index (2017=100)  92.779  92.841  106.275   99.772   94.378  ...   95.217
# 2  Index (2017=100)  94.611  94.863   92.812   95.264   98.879  ...   98.800
# 3  Index (2017=100)  94.132  94.271   96.365  100.418  100.516  ...  103.521
# 4  Index (2017=100)  83.296  85.382   89.426   91.852   91.820  ...   93.341
#
#       2015     2016   2017     2018     2019     2020     2021     2022  \
# 0   98.811   98.859  100.0  101.089  102.665  106.346  107.076  106.151
# 1   97.048   98.582  100.0   95.548   92.722  100.851   99.282   93.051
# 2   97.511   98.976  100.0  101.491  103.499  108.574  113.423  109.700
# 3  102.602  102.102  100.0  100.728  101.374  107.309  107.508  105.726
# 4   95.603   96.438  100.0  102.159  107.356  117.005  120.095  115.262
#
#       2023
# 0  107.992
# 1  100.303
# 2  109.179
# 3  106.947
# 4  118.074
#
# [5 rows x 22 columns]

# %%
#| echo: false
#| code-fold: true
#| include: false

lab_pdt_2023 = lab_pdt[lab_pdt['Area'].isin(state_names.values())]
lab_pdt_2023 = lab_pdt_2023[["Area","2023"]]
lab_pdt_2023.rename(columns={'Area': 'State', '2023': 'Labor_Productivity_2023'}, inplace=True)

# %%
#| echo: false
#| code-fold: true
#| include: false

# All dataset
USA_acs_data
US_netexport_2023
bea_state_tbl
life_df
lab_pdt_2023
# Out:
#                    State  Labor_Productivity_2023
# 0                Alabama                  107.992
# 1                 Alaska                  100.303
# 2                Arizona                  109.179
# 3               Arkansas                  106.947
# 4             California                  118.074
# 5               Colorado                  115.671
# 6            Connecticut                  103.346
# 7               Delaware                  101.073
# 8   District of Columbia                  114.806
# 9                Florida                  112.931
# 10               Georgia                  104.667
# 11                Hawaii                   99.788
# 12                 Idaho                  112.662
# 13              Illinois                  106.842
# 14               Indiana                  111.292
# 15                  Iowa                  103.393
# 16                Kansas                  108.006
# 17              Kentucky                  107.007
# 18             Louisiana                   98.811
# 19                 Maine                  115.711
# 20              Maryland                  109.428
# 21         Massachusetts                  116.072
# 22              Michigan                  107.504
# 23             Minnesota                  107.390
# 24           Mississippi                  102.623
# 25              Missouri                  109.715
# 26               Montana                  102.921
# 27              Nebraska                  120.151
# 28                Nevada                  100.565
# 29         New Hampshire                  111.814
# 30            New Jersey                  108.088
# 31            New Mexico                  110.286
# 32              New York                  108.494
# 33        North Carolina                  105.774
# 34          North Dakota                   99.667
# 35                  Ohio                  107.278
# 36              Oklahoma                  100.616
# 37                Oregon                  111.063
# 38          Pennsylvania                  103.329
# 39          Rhode Island                  101.389
# 40        South Carolina                  104.611
# 41          South Dakota                   97.433
# 42             Tennessee                  112.898
# 43                 Texas                  106.564
# 44                  Utah                  116.077
# 45               Vermont                  108.206
# 46              Virginia                  114.121
# 47            Washington                  124.929
# 48         West Virginia                  106.637
# 49             Wisconsin                  108.181
# 50               Wyoming                  102.393

# %%
#| echo: false
#| code-fold: true
#| include: false

# Join ACS and netexport
df1 = USA_acs_data.merge(US_netexport_2023[['STATE_NAME', 'netexport']], left_on='NAME', right_on='STATE_NAME', how='left').drop(
    columns=["STATE_NAME"]
)

# Join bea_state_tbl
df2 = df1.merge(bea_state_tbl[['GeoName', 'REALGDP']], left_on='NAME', right_on='GeoName', how='left').drop(
    columns=["GeoName"]
)

# Join life_df
df3 = df2.merge(life_df[['area', 'life_expectancy']], left_on='NAME', right_on='area', how='left').drop(
    columns=["area"]
)

# Join lab_pdt_2023
df4 = df3.merge(lab_pdt_2023, left_on='NAME', right_on='State', how='left').drop(
    columns=["State"]
)

# Create Real GDP per capita
df4["REALGDPpercapita"] = (df4["REALGDP"]*10**6)/df4["TotalPop"]

# %%
#| echo: false
#| code-fold: true
#| include: false

# Get geographies of US States
import pygris
from pygris import states
from pygris.utils import shift_geometry

# %%
#| echo: false
#| code-fold: true
#| include: false

us = states(cb = True, resolution = "20m", year=2023)
us_rescaled = shift_geometry(us)
us_rescaled.plot()
# Out:
# <Axes: >

# %%
#| echo: false
#| code-fold: true
#| include: false

# Join the data to geography
us_rescaled.head()
# Out:
#   STATEFP   STATENS      GEOIDFQ GEOID STUSPS        NAME LSAD         ALAND  \
# 0      48  01779801  0400000US48    48     TX       Texas   00  676686238592
# 1      06  01779778  0400000US06    06     CA  California   00  403673296401
# 2      21  01779786  0400000US21    21     KY    Kentucky   00  102266598312
# 3      13  01705317  0400000US13    13     GA     Georgia   00  149485311347
# 4      55  01779806  0400000US55    55     WI   Wisconsin   00  140292627460
#
#         AWATER                                           geometry
# 0  18982083586  POLYGON ((-998043.807 -568739.971, -997956.109...
# 1  20291770234  MULTIPOLYGON (((-2066284.899 -204542.622, -205...
# 2   2384223544  POLYGON ((571924.530 -84268.109, 577745.348 -8...
# 3   4419673221  POLYGON ((939223.082 -230281.864, 951008.202 -...
# 4  29343084365  MULTIPOLYGON (((708320.068 919586.190, 715683....

# %%
#| echo: false
#| code-fold: true
#| include: false

us_rescaled_final = us_rescaled.merge(
    df4,
    left_on=["GEOID"],
    right_on=["state"],
).drop(
    columns=["state"]
)

# Convert CRS
us_rescaled_final = us_rescaled_final.to_crs("EPSG:4326")

# %%
#| echo: false
#| code-fold: true
#| include: false

us_rescaled_final.columns
# Out:
# Index(['STATEFP', 'STATENS', 'GEOIDFQ', 'GEOID', 'STUSPS', 'NAME_x', 'LSAD',
#        'ALAND', 'AWATER', 'geometry', 'NAME_y', 'GEO_ID', 'MedHHInc',
#        'EducTotal', 'EducBelowHighSch', 'EducHighSch', 'EducAssoc', 'EducBach',
#        'TotalPop', 'TotalPop16', 'LabForTotal', 'Unemployed',
#        'PopPovertyDetermined', 'PovertyPop', 'PctBach', 'PovertyRate',
#        'UnemploymentRate', 'LabForParticipationRate', 'netexport', 'REALGDP',
#        'life_expectancy', 'Labor_Productivity_2023', 'REALGDPpercapita'],
#       dtype='object')

# %%
#| echo: false
#| code-fold: true
#| include: false

import matplotlib.pyplot as plt
import seaborn as sns

# %%
#| echo: false
#| code-fold: true
#| include: false

# Create a list of all variables
variables = ['MedHHInc','TotalPop', 'TotalPop16', 'LabForTotal', 'Unemployed','PctBach', 'PovertyRate', 'UnemploymentRate', 'LabForParticipationRate', 'netexport', 'REALGDP', 'life_expectancy', 'Labor_Productivity_2023', 'REALGDPpercapita']

# Create a list of selected variables for later analysis
selected_variables = ['REALGDPpercapita','life_expectancy','MedHHInc','PctBach','UnemploymentRate','LabForParticipationRate', 'Labor_Productivity_2023', 'TotalPop', 'PovertyRate', 'netexport']

# Calculate the correlation matrix
corr_matrix = us_rescaled_final[variables].corr()

# Plot the correlation matrix using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # 4. Cluster Analysis
#
# We can apply K-means clustering to try and identify which states are more developed/deprived than others. Clustering is an unsupervised classification of patterns (i.e., GDP per capita and life expectancy across states) into similar groups (clusters), and k-means does this by classifying the states into k-number of groups.

# %%
#| include: false
# !pip install kneed
from kneed import KneeLocator
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from sklearn.preprocessing import StandardScaler
# Out:
# Requirement already satisfied: kneed in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (0.8.3)
# Requirement already satisfied: numpy>=1.14.2 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from kneed) (1.24.4)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages (from kneed) (1.14.1)

# %% [markdown]
# Since our data set has values of different magnitude, we first standardise our variables.

# %%
scaler = StandardScaler()

# %%
us_rescaled_final_scaled = scaler.fit_transform(us_rescaled_final[selected_variables])

# %%
#| include: false
us_rescaled_final_scaled[:5]
# Out:
# array([[ 0.18487338, -0.24809861, -0.14805012,  0.04993213,  0.32039385,
#          0.41554238, -0.23313867,  3.14989957,  0.60081221,  1.69668282],
#        [ 0.6841054 ,  0.98323645,  1.41156863,  0.47528874,  1.6001672 ,
#          0.02104807,  1.72321452,  4.45798269, -0.10626238, -4.96593234],
#        [-0.68639981, -1.56435333, -1.22776822, -1.71081504,  0.02183141,
#         -1.16883736, -0.15784202, -0.27335768,  1.50073665, -0.20859323],
#        [-0.15061751, -0.71515674, -0.27473705, -0.08819599,  0.28807508,
#         -0.02336489, -0.55557151,  0.58646986,  0.47472164, -1.29738548],
#        [-0.32423353,  0.7709373 , -0.19645262,  0.21207503, -1.50918507,
#          0.48485053,  0.04170261, -0.08519173, -0.64064509,  0.20815182]])

# %% [markdown]
# We then run the kneed package to find an optimal number of k clusters.

# %%
# Number of clusters to try out
n_clusters = list(range(2, 10))

# Run kmeans for each value of k
inertias = []
for k in n_clusters:
    
    # Initialize and run
    kmeans = KMeans(n_clusters=k, n_init=10)
    kmeans.fit(us_rescaled_final_scaled)
    
    # Save the "inertia"
    inertias.append(kmeans.inertia_)

# Initialize the knee algorithm
kn = KneeLocator(n_clusters, inertias, curve='convex', direction='decreasing')

# Print out the knee 
print(kn.knee)
# Out:
# 6
# c:\Users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# Run the k-means clustering with the optimal k value. We can visualise the results in the table and map below.

# %%
kmeans = KMeans(n_clusters=6, n_init=10)

# Perform the fit
kmeans.fit(us_rescaled_final_scaled)

# Extract the labels
us_rescaled_final['label'] = kmeans.labels_
# Out:
# c:\Users\jiayu\miniforge3\envs\musa-550-fall-2023\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# Number of states per cluster
us_rescaled_final.groupby('label', as_index=False).size()
# Out:
#    label  size
# 0      0    16
# 1      1     9
# 2      2     1
# 3      3    14
# 4      4    10
# 5      5     1

# %%
# Average feature per cluster
us_rescaled_final.groupby("label", as_index=False)[
    selected_variables
].mean().sort_values(by="label")
# Out:
#    label  REALGDPpercapita  life_expectancy       MedHHInc   PctBach  \
# 0      0      63641.287918        77.162500   79378.875000  0.217191
# 1      1      48835.305886        72.233333   60957.555556  0.164726
# 2      2     217272.523022        75.300000  106287.000000  0.260746
# 3      3      63293.022605        75.364286   73875.857143  0.201638
# 4      4      73713.193650        78.180000   93235.800000  0.244063
# 5      5      82783.538426        78.300000   96334.000000  0.224029
#
#    UnemploymentRate  LabForParticipationRate  Labor_Productivity_2023  \
# 0          0.041852                 0.649131               104.720938
# 1          0.053548                 0.584285               105.058889
# 2          0.064270                 0.719794               114.806000
# 3          0.051788                 0.628321               107.645143
# 4          0.043336                 0.672959               114.374100
# 5          0.063654                 0.638570               118.074000
#
#        TotalPop  PovertyRate     netexport
# 0  1.963924e+06     0.108652 -1.437363e+09
# 1  3.697484e+06     0.166678 -9.561401e+08
# 2  6.720790e+05     0.145306  1.553795e+08
# 3  1.219532e+07     0.128928 -4.489356e+10
# 4  5.703807e+06     0.093520 -1.743753e+10
# 5  3.924278e+07     0.119664 -2.715042e+11

# %%
import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Map plot clusters
us_rescaled_final.hvplot(
    c="label",
    dynamic=False,
    width=1000,
    height=1000,
    geo=True,
    cmap="viridis",
    )
# Out:
# :Polygons   [Longitude,Latitude]   (label)

# %% [markdown]
# States in Cluster 1 appear to be the worst off economically across most of the 10 variables compared to other clusters. Cluster 3 has the lowest mean value in real GDP per capita, life expectancy, median household income, percentage of bachelor's degree, labour participation rate, and highest mean value in poverty rate.
#
# Clusters 2 and 5 have only 1 state, District of Columbia and California respectively. Both clusters have high median household income and real GDP per capita, and labor productivity
#
# One limitation of cluster is its unsupervised nature. This means that it is possible for the clusters to be unrelated to development/deprivation. Nonetheless, the results from our table suggest that the classification are related to level of economic development/deprivation.
